# %% [markdown]
# ## **EJ6_FICHEROS, FECHAS, EXCEPCIONES** - Álvaro Fernandez Becerra

# %% [markdown]
# #### 1.	Haciendo uso del fichero stock.csv realiza un programa que abra el fichero, lea sus datos y los almacene en una lista de diccionarios. Después imprime en pantalla el stock de cada material. Prueba a hacerlo con y sin usar la estructura “with” de acceso a fichero.

# %%
# Abrir el csv y leer su contenido
with open('stock.csv', 'r') as f1:
    # Obtener cabeceras, crear diccionarios con nombre de la cabecera:
    cabeceras = f1.readline().strip().split(',')
    #Crear diccionarios
    for cabecera in cabeceras:
        cabecera = {'Nombre': cabecera, 'Stock': 0}

    #Leer resto de lineas, modificar el stock de cada producto
    contenido = f1.readlines()
    for linea in contenido:
        valores = linea.strip().split(',')
        diccionarios = {cabeceras[i]: valores[i] for i in range(len(cabeceras))}
        print(diccionarios)
    #cerrar
f1.close()
# Out:
# {'tornillos': '100', 'tuercas': '150', 'arandelas': '300'}
# {'tornillos': '120', 'tuercas': '120', 'arandelas': '250'}
# {'tornillos': '80', 'tuercas': '90', 'arandelas': '180'}
# {'tornillos': '70', 'tuercas': '60', 'arandelas': '150'}
# {'tornillos': '50', 'tuercas': '50', 'arandelas': '100'}
# {'tornillos': '25', 'tuercas': '30', 'arandelas': '50'}

# %% [markdown]
# #### 2.	Haciendo uso del fichero stock.csv realiza un programa que abra el fichero, lea los datos y almacene en un diccionario la cantidad acumulada de cada uno de los materiales (arandelas, tornillos y tuercas). Después pregunta al usuario de qué material quiere conocer el stock y muéstralo por pantalla.
# - Añade control de excepciones en tu código. Razonamos dónde es necesario.

# %%
# Diccionario stock:
stock = {'tornillos': 0, 'tuercas': 0, 'arandelas': 0}
try:
    with open('stock.csv', 'r') as fich:
        next(fich)  # Saltar la cabecera
        for linea in fich:
            stock['tornillos'] += int(linea.split(',')[0])
            stock['tuercas'] += int(linea.split(',')[1])
            stock['arandelas'] += int(linea.split(',')[2])
        
except FileNotFoundError:
    print("Error:  fichero no encontrado.")
else:
    material = input('Qué material quieres consultar (tornillos/tuercas/arandelas) ').strip().lower()
    if material == 'tornillos':
        print(f"Cantidad de tornillos: {stock['tornillos']}")
    elif material == 'tuercas':
        print(f"Cantidad de tuercas: {stock['tuercas']}")
    elif material == 'arandelas':
        print(f"Cantidad de arandelas: {stock['arandelas']}")
    else:
        print("No existe ese material.")
finally:
    fich.close()
    print(stock)
# Out:
# Cantidad de tornillos: 445
# {'tornillos': 445, 'tuercas': 500, 'arandelas': 1030}

# %% [markdown]
# #### 3.	Haciendo uso del fichero alturas.csv calcula la altura promedio de un género dado por el usuario.
# - Añade control de excepciones en tu código. Razonamos dónde es necesario.

# %%
try:
    gen = str(input("Que género quieres consultar (Femenino/Masculino)? ").strip().lower())
    if gen not in ("femenino", "masculino"):
        raise ValueError("Género no válido. Debe ser 'Femenino' o 'Masculino'.")

    with open('alturas.csv', 'r') as fich:
        next(fich)
        total_altura = 0 # *pulgadas
        cantidad = 0
        # recorrer lineas, calcular altura total
        for linea in fich:
            if linea.split(',')[0].strip().lower() == gen:
                total_altura += float(linea.split(',')[1])
                cantidad += 1
        # si se ha calculado la altura (genero existente)
        if cantidad > 0:
            total_altura = total_altura * 0.0254  # metrps
            media = total_altura / cantidad

except FileNotFoundError:
    print("Error:  fichero no encontrado.")
else:
    print(f"La altura promedio de {gen} es {media:.2f} metros.")
finally:
    pass
# Out:
# La altura promedio de femenino es 1.62 metros.

# %% [markdown]
# #### 4.	Utilizando el fichero notas.csv, realiza un programa en python que lea los datos de ese fichero y construya la siguiente estructura:
#
# `alumnos = [ {"nombre":"Daniel", "apellidos":"Fustero López", "curso": "1A","notas":{"FH":3,"LM":4,"ISO":5,"FOL":6,"PAR":7,"SGBG":6}},
# {"nombre":"Rafaela", ... },...]
# `
#
# El programa debe mostrar un menú con las siguientes opciones:
# - Muestra el listado de los alumnos con la nota media que han sacado. Utiliza una función para realizar el cálculo de la nota media.
# - Pide un curso y una asignatura y muestra una lista de los alumnos de ese curso con las notas en esa asignatura.
# - Pide un curso y muestra el porcentaje de aprobados por cada asignatura.
# - Pide un curso, y crea un fichero nombredelcurso.txt con los alumnos y la nota media.

# %%
def calc_media(notas):
    return sum(notas) / len(notas)

alumnos = []
try:
    with open('notas.csv', 'r', encoding='utf-8') as fich:
        cabeceras = fich.readline().strip().split(',')
        contenido = fich.readlines()
        for linea in contenido:
            alumno = {}
            notas = {}
            valores = linea.strip().split(',')
            alumno[cabeceras[1]] = valores[1]
            alumno[cabeceras[0]] = valores[0]
            
            #desde la 4a columna hasta el final:
            for i in range(4, len(cabeceras)):
                notas[cabeceras[i]] = int(valores[i])
            alumno['notas'] = notas
            #añadir a la lista
            alumnos.append(alumno)
            
except FileNotFoundError:
    print("No se encontro el fichero")
else:
    pass
alumnos
# Out:
# [{'Nombre': ' DANIE', 'Apellidos': 'ACEVEDO JHONG'},
#  {'Nombre': ' MIGUELVICENT', 'Apellidos': 'AGURTO RONDOY'},
#  {'Nombre': ' CHRISTIAN NELSO', 'Apellidos': 'ALCALÁ NEGRÓN'},
#  {'Nombre': ' RAUL EDUARD', 'Apellidos': 'ALMORA HERNANDEZ'},
#  {'Nombre': ' JORGE', 'Apellidos': 'ALOSILLA VELAZCO VERA'},
#  {'Nombre': ' VICTO', 'Apellidos': 'ALVA CAMPOS'},
#  {'Nombre': ' JAVIE', 'Apellidos': 'AREVALO LOPEZ'},
#  {'Nombre': ' ROSARI', 'Apellidos': 'ARIAS HERNANDEZ'},
#  {'Nombre': ' EFRAÍN', 'Apellidos': 'ARROYO RAMÍREZ'},
#  {'Nombre': ' MARCO TULI', 'Apellidos': 'ALOCEN BARRERA'},
#  {'Nombre': ' CESA', 'Apellidos': 'BAIOCCHI URETA'},
#  {'Nombre': ' ISELA FLO', 'Apellidos': 'BAYLÓN ROJAS'},
#  {'Nombre': ' LEONCI', 'Apellidos': 'BEDOYA CASTILLO'},
#  {'Nombre': ' LUZ MARIN', 'Apellidos': 'BEDREGAL CANALES'},
#  {'Nombre': ' RAMIRO ALBERT', 'Apellidos': 'BEJAR TORRES'},
#  {'Nombre': ' JAVIE', 'Apellidos': 'BENAVIDES ESPEJO'},
#  {'Nombre': ' NELSO', 'Apellidos': 'BOZA SOLIS'},
#  {'Nombre': ' CIELITO MERCEDE', 'Apellidos': 'CALLE BETANCOURT'},
#  {'Nombre': ' ISABEL FLORIS', 'Apellidos': 'CARAZA VILLEGAS'},
#  {'Nombre': ' GIZELL', 'Apellidos': 'CARRERA ABANTO'},
#  {'Nombre': ' ESTALIN', 'Apellidos': 'CARRILLO SEGURA'},
#  {'Nombre': ' JORGE AUGUST', 'Apellidos': 'CARRIÓN NEIRA'},
#  {'Nombre': ' GUILLERMO', 'Apellidos': 'CASAPIA VALDIVIA'},
#  {'Nombre': ' ZARIT', 'Apellidos': 'CHANCOS MENDOZA'},
#  {'Nombre': ' CARLO', 'Apellidos': 'CHIRINOS LACOTERA'},
#  {'Nombre': ' DORI', 'Apellidos': 'CORES MORENO'},
#  {'Nombre': ' MARIBEL CORIN', 'Apellidos': 'CORTEZ LOZANO'},
#  {'Nombre': ' ANGE', 'Apellidos': 'CRISPIN QUISPE'},
#  {'Nombre': ' ANTONIO', 'Apellidos': 'DE LOAYZA CONTERNO'},
#  {'Nombre': ' ANA MARI', 'Apellidos': 'DIAZ SALINAS'},
#  {'Nombre': ' ANTONIO', 'Apellidos': 'DUEÑAS ARISTISABAL'},
#  {'Nombre': ' YULIAN', 'Apellidos': 'ESPINOZA ARANA'},
#  {'Nombre': ' CARLOS ENRIQU', 'Apellidos': 'FERNANDEZ GUZMAN'},
#  {'Nombre': ' ESTHER AUROR', 'Apellidos': 'FERNANDEZ MATTA'},
#  {'Nombre': ' OLG', 'Apellidos': 'FERRO SALAS'},
#  {'Nombre': ' EDWI', 'Apellidos': 'FLORES ROMERO'},
#  {'Nombre': ' ROBERT', 'Apellidos': 'GAMARRA ASTETE'},
#  {'Nombre': ' GLORI', 'Apellidos': 'GAMIO LOZANO'},
#  {'Nombre': ' MIRIA', 'Apellidos': 'GARCÍA PERALTA'},
#  {'Nombre': ' ARTUR', 'Apellidos': 'GONZALES DEL VALLE MAGUIÑO'},
#  {'Nombre': ' MARLENE VICTORI', 'Apellidos': 'GONZALES HUILCA'},
#  {'Nombre': ' ELSA PATRICI', 'Apellidos': 'GONZALES MEDINA'},
#  {'Nombre': ' JAVIE', 'Apellidos': 'GUTIERREZ VELEZ'},
#  {'Nombre': ' ELENA ROSAVEL', 'Apellidos': 'GUZMAN CHINAG'},
#  {'Nombre': ' CLAR', 'Apellidos': 'GUZMAN QUISPE'},
#  {'Nombre': ' MILAGROS SUSAN', 'Apellidos': 'HERRERA CARBAJAL'},
#  {'Nombre': ' GUILLERM', 'Apellidos': 'HORRUITINER MARTINEZ'},
#  {'Nombre': ' LOURDE', 'Apellidos': 'HUAMANI FLORES'},
#  {'Nombre': ' LUIS ARMAND', 'Apellidos': 'HUAPAYA RAYGADA'},
#  {'Nombre': ' MARCO', 'Apellidos': 'HUARCAYA QUISPE'},
#  {'Nombre': ' WALTER DAVI', 'Apellidos': 'HUAYTAN SAUÑE'},
#  {'Nombre': ' ELBA MERCEDES', 'Apellidos': 'LA ROSA FABIAN'},
#  {'Nombre': ' PEDRO GUILLERM', 'Apellidos': 'LANDA GINOCCHIO'},
#  {'Nombre': ' ROBERTO JULIA', 'Apellidos': 'LLAJA TAFUR'},
#  {'Nombre': ' ORFELIN', 'Apellidos': 'LLENPEN NUÑEZ'},
#  {'Nombre': ' HECTO', 'Apellidos': 'LUJAN VENEGAS'},
#  {'Nombre': ' GISSEL', 'Apellidos': 'MAGUIÑA SAN YEN MAN'},
#  {'Nombre': ' COSME ADOLF', 'Apellidos': 'MALDONADO QUISPE'},
#  {'Nombre': ' SANDRA MONIC', 'Apellidos': 'MALDONADO TINCO'},
#  {'Nombre': ' JENNY MARI', 'Apellidos': 'MALLQUI CELESTINO'},
#  {'Nombre': ' SANTIAG', 'Apellidos': 'MAMANI UCHASARA'},
#  {'Nombre': ' MAGDA JANET', 'Apellidos': 'MARAVI NAVARRO'},
#  {'Nombre': ' MARTI', 'Apellidos': 'MARTINEZ MARQUEZ'},
#  {'Nombre': ' OSCAR ENRIQU', 'Apellidos': 'MEDINA ZUTA'},
#  {'Nombre': ' CARLOS ', 'Apellidos': 'MELGAREJO VIBES'},
#  {'Nombre': ' ELIZABET', 'Apellidos': 'MIGUEL HOLGADO'},
#  {'Nombre': ' MANUEL ANTONI', 'Apellidos': 'MORI RAMIREZ'},
#  {'Nombre': ' CARLOS ALBERT', 'Apellidos': 'NUÑEZ HUAYANAY'},
#  {'Nombre': ' OLG', 'Apellidos': 'ORE REYES'},
#  {'Nombre': ' JOSU', 'Apellidos': 'ORRILLO ORTIZ'},
#  {'Nombre': ' JOSUÉ VICTO', 'Apellidos': 'ORRILLO ORTIZ'},
#  {'Nombre': ' CARMEN ROS', 'Apellidos': 'PARDAVE CAMACHO'},
#  {'Nombre': ' SANTIAGO VICTO', 'Apellidos': 'PAREDES JARAMILLO'},
#  {'Nombre': ' ARTUR', 'Apellidos': 'PASTOR PORRAS'},
#  {'Nombre': ' ENRIQU', 'Apellidos': 'PINEDO NUÑEZ'},
#  {'Nombre': ' SONI', 'Apellidos': 'PRADA VILCHEZ'},
#  {'Nombre': ' GERARDO DAVI', 'Apellidos': 'RIEGA CALLE'},
#  {'Nombre': ' FREDD', 'Apellidos': 'RIOS LIMA'},
#  {'Nombre': ' TERES', 'Apellidos': 'RIOS LIMA'},
#  {'Nombre': ' JUAN ELVI', 'Apellidos': 'RIQUELME MIRANDA'},
#  {'Nombre': ' GEORGINA ESPERANZ', 'Apellidos': 'ROA YANAC'},
#  {'Nombre': ' ROSA LILIAN', 'Apellidos': 'ROBLES VALVERDE'},
#  {'Nombre': ' ROSA JOSEF', 'Apellidos': 'RODRIGUEZ FARIAS'},
#  {'Nombre': ' MARIA DE FATIM', 'Apellidos': 'ROJAS VALDIVIA'},
#  {'Nombre': ' ROSA MARI', 'Apellidos': 'ROMERO GOMEZ SANCHEZ'},
#  {'Nombre': ' CARINA MAGNOLI', 'Apellidos': 'ROSALES FLORES'},
#  {'Nombre': ' CARLOS JOS', 'Apellidos': 'ROSAS BONIFAZ'},
#  {'Nombre': ' AIDA CRISTIN', 'Apellidos': 'RUIZ DE CASTILLA BRITTO'},
#  {'Nombre': ' CELI', 'Apellidos': 'SALCEDO DEL PINO'},
#  {'Nombre': ' VIOLETA MARIL', 'Apellidos': 'SALINAS PUCCIO'},
#  {'Nombre': ' AUGUST', 'Apellidos': 'SANCHEZ ARONE'},
#  {'Nombre': ' PEDRO MANUE', 'Apellidos': 'SANTA CRUZ BENSSA'},
#  {'Nombre': ' ANGE', 'Apellidos': 'SOLANO VARGAS'},
#  {'Nombre': ' JOSE ALBERT', 'Apellidos': 'TEJEDO LUNA'},
#  {'Nombre': ' ANGEL', 'Apellidos': 'TENORIO DAVILA'},
#  {'Nombre': ' MIGUEL ANGEL', 'Apellidos': 'TORRES GASPAR'},
#  {'Nombre': ' JACQUELI', 'Apellidos': 'TRUJILLO PARODI'},
#  {'Nombre': ' RUTH NORICIL', 'Apellidos': 'VEGA CARREAZO'},
#  {'Nombre': ' GUILLERMO JONATHA', 'Apellidos': 'VELASQUEZ RAMOS'},
#  {'Nombre': ' ALEJANDR', 'Apellidos': 'VERA SILVA'},
#  {'Nombre': ' BLANCA KATT', 'Apellidos': 'VILCA LUCERO'},
#  {'Nombre': ' ENRIQUE GODOFRED', 'Apellidos': 'VILGOSO ALVARADO'},
#  {'Nombre': ' CECILI', 'Apellidos': 'YAMAWAKI ONAGA'},
#  {'Nombre': ' MARIELA MILAGRO', 'Apellidos': 'ZAMALLOA VEGA'},
#  {'Nombre': ' MONICA', 'Apellidos': 'ZAPATA CHANG'},
#  {'Nombre': ' JUAN CARLO', 'Apellidos': 'ZEGARRA SALCEDO'},
#  {'Nombre': ' HILRICH MARIE', 'Apellidos': 'ZU FLORES'}]
